# %% [markdown]
# # render-latex.nvim + jupynvim
#
# This notebook mixes Python code cells with Markdown cells containing display math.
#
# The equation below should render as an image inside this Markdown cell:
#
# $$
# E = mc^2
# $$

# %%
import math

radius = 3
area = math.pi * radius ** 2
area

# %% [markdown]
# The plugin should also render bracket display math in Markdown cells:
#
# \[
# \int_0^1 x^2 \, dx = \frac{1}{3}
# \]
#
# Inline math like `$x^2$` is intentionally left to jupynvim in this repro.

# %%
# These dollar fences are inside a Python code cell and should stay raw.
raw_latex = '''
$$
x^2 + y^2 = z^2
$$
'''
print(raw_latex.strip())

# %% [markdown]
# A final Markdown display equation should render too:
#
# $$
# a^2 + b^2 = c^2
# $$
